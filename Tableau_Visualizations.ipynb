# %% [markdown]
# **Q9. Chart Selection Justification**
#
# **Explain why different charts were used for different business questions in this analysis**
#
# Answer ▶
#
# The effectiveness of a Tableau analysis depends on matching the right visual encoding (shape, color, size) to the specific business question. In this project, each chart was selected to reduce "cognitive load"—allowing a stakeholder to understand the data without having to perform mental math.
#
# **Q10. Business Insight Summary**
#
# **Summarize two key insights from your dashboard and explain how they can help management make better decisions.**
#
# Answer ▶
#
# 1. High Sales Volume vs. Profit Instability
#
# The Profitability Investigation scatter plot reveals a significant number of orders (pink dots) falling below the zero-line. This shows that despite high sales revenue, several transactions are resulting in net losses.
#
# - Management Decision: Leadership can use this to investigate the root causes of losses, such as excessive discounting, high shipping costs, or specific low-margin product categories. They can then implement a "minimum margin" policy or adjust pricing strategies to ensure that high-volume orders actually contribute to the bottom line.
#
# 2. Seasonal Sales Volatility (January Spike vs. November Dip)
#
# The Sales Trend Analysis shows a massive peak in January (163,217) followed by a sharp decline, with a significant low point in November (62,142).
#
# - Management Decision: This insight helps in resource and inventory planning. Management can allocate higher marketing budgets and staffing for the January surge, while developing "off-season" promotions or loyalty programs to stabilize revenue during the November slump.
